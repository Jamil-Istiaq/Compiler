# %% [markdown]
# # --------ResNet50--------

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from keras.applications.vgg16 import preprocess_input

import os
import cv2
from os import walk
import glob as gb
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
SEED = 1000
IMG_SIZE = 100
BATCH_SIZE = 24

TRAIN_DIR = 'D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/train'
VALID_DIR = 'D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/valid'
TEST_DIR = 'D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/test'

# %%
class_names = []
class_count = []
TRAIN_EXAMPLES = 0
for folder in  os.listdir(TRAIN_DIR) : 
    files = gb.glob(pathname= str( TRAIN_DIR + '//' + folder + '/*'))
    class_names.append(folder)
    class_count.append(len(files))
    TRAIN_EXAMPLES += len(files)

plt.figure(figsize=(25,10))    
sns.barplot(x = class_names, y=class_count).set_title("Distribution across classes in training set")
plt.show()

print(f'Total Train Examples = {TRAIN_EXAMPLES}')
# Out:
# Total Train Examples = 3491

# %%
class_names = []
class_count = []
Test_EXAMPLES = 0
for folder in  os.listdir(TEST_DIR) : 
    files = gb.glob(pathname= str( TEST_DIR + '//' + folder + '/*'))
    class_names.append(folder)
    class_count.append(len(files))
    Test_EXAMPLES += len(files)

plt.figure(figsize=(25,10))     
sns.barplot(x = class_names, y=class_count).set_title("Distribution across classes in Test set")
plt.show()

print(f'Total Test Examples = {Test_EXAMPLES}')
# Out:
# Total Test Examples = 200

# %%
class_names = []
class_count = []
VALIDATION_EXAMPLES = 0
for folder in  os.listdir(VALID_DIR) : 
    files = gb.glob(pathname= str( VALID_DIR + '//' + folder + '/*'))
    class_names.append(folder)
    class_count.append(len(files))
    VALIDATION_EXAMPLES += len(files)

plt.figure(figsize=(25,10))     
sns.barplot(x = class_names, y=class_count).set_title("Distribution across classes in Valid set")
plt.show()

print(f'Total Validation Examples = {VALIDATION_EXAMPLES}')
# Out:
# Total Validation Examples = 200

# %%
# diaplay 5 images from each class
plt.figure(figsize=(12,12))
i=0
for c in os.listdir(TRAIN_DIR):  
    path = os.path.join(TRAIN_DIR,c)
    for img in os.listdir(path):
        img_array = cv2.cvtColor(cv2.imread(os.path.join(path,img)), cv2.COLOR_BGR2RGB) 
        plt.subplot(2,5,i+1)
        plt.imshow(img_array)
        if i%5 == 0:
            plt.ylabel(c)
        plt.xticks([])
        plt.yticks([])
        i += 1
        if i%5 == 0:
            break

plt.tight_layout()        
plt.show()

# %%
train_gen = ImageDataGenerator(
    
    featurewise_center=False,
    
    samplewise_center=False,
    
    featurewise_std_normalization=False,
    
    samplewise_std_normalization=False,
    
    zca_whitening=False,
    
    zca_epsilon=1e-06,
    
    rotation_range=0.0,
    
    width_shift_range=0.2,
    
    height_shift_range=0.2,
    
    shear_range=0.2,
    
    zoom_range=0.3,
    
    channel_shift_range=0.,
    
    fill_mode='nearest',
    
    cval=0.,
    
    horizontal_flip=False,
    
    vertical_flip=False,
    
    rescale=None,
    
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
    
    data_format=None,
    
    
    validation_split=0.0,
    
    dtype=tf.float32,
)

test_gen = ImageDataGenerator(
    preprocessing_function= tf.keras.applications.resnet50.preprocess_input, 
    dtype=tf.float32
)

# %%
train_batch = train_gen.flow_from_directory(
    directory = TRAIN_DIR,
    target_size = (IMG_SIZE,IMG_SIZE),
    batch_size = BATCH_SIZE,
    class_mode = 'sparse',
    seed = SEED
)
# Out:
# Found 3491 images belonging to 2 classes.

# %%
imgs, labels = next(train_batch)
i = 0
plt.figure(figsize=(20,7))
for img, label in zip(imgs, labels):
    plt.subplot(2,8,i+1)
    plt.imshow(img.astype('uint8'))
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(class_names[label.astype('int32')])
    i+=1
    if i == 16:
        break
        
plt.tight_layout()
plt.show()

# %%
valid_batch = train_gen.flow_from_directory(
    directory = VALID_DIR,
    target_size = (IMG_SIZE,IMG_SIZE),
    batch_size = BATCH_SIZE,
    class_mode = 'sparse',
    seed = SEED
)
# Out:
# Found 200 images belonging to 2 classes.

# %%
test_batch = test_gen.flow_from_directory(
    directory = TEST_DIR,
    target_size = (IMG_SIZE,IMG_SIZE),
    batch_size = BATCH_SIZE,
    class_mode = 'sparse',
    seed = SEED
)
# Out:
# Found 200 images belonging to 2 classes.

# %%
def identity_block(X, filters):
    f1, f2, f3 = filters
    X_copy = X
    
    
    X = layers.Conv2D(filters=f1, kernel_size=(1,1), strides=(1,1), padding='valid')(X)
    X = layers.BatchNormalization(axis=3)(X)
    X = layers.Activation('relu')(X)
    
    
    X = layers.Conv2D(filters=f2, kernel_size=(3,3), strides=(1,1), padding='same')(X)
    X = layers.BatchNormalization(axis=3)(X)
    X = layers.Activation('relu')(X) 
    
   
    X = layers.Conv2D(filters=f3, kernel_size=(1,1), strides=(1,1), padding='valid')(X)
    X = layers.BatchNormalization(axis=3)(X)
    
   
    X = layers.Add()([X, X_copy])
    X = layers.Activation('relu')(X)
    
    return X

# %%
def conv_blocks(X, filters, s=2):
    f1, f2, f3 = filters
    X_copy = X
    
    
    X = layers.Conv2D(filters=f1, kernel_size=(1,1), strides=(s,s), padding='valid')(X)
    X = layers.BatchNormalization(axis=3)(X)
    X = layers.Activation('relu')(X)
    
    
    X = layers.Conv2D(filters=f2, kernel_size=(3,3), strides=(1,1), padding='same')(X)
    X = layers.BatchNormalization(axis=3)(X)
    X = layers.Activation('relu')(X) 
    
    
    X = layers.Conv2D(filters=f3, kernel_size=(1,1), strides=(1,1), padding='valid')(X)
    X = layers.BatchNormalization(axis=3)(X)
    
    
    X_copy = layers.Conv2D(filters=f3, kernel_size=(1,1), strides=(s,s), padding='valid')(X_copy)
    X_copy = layers.BatchNormalization(axis=3)(X_copy)
    
    
    X = layers.Add()([X, X_copy])
    X = layers.Activation('relu')(X)
    
    return X

# %%
def ResNet50():
    X_input = keras.Input((IMG_SIZE, IMG_SIZE, 3))
    X = layers.ZeroPadding2D((3,3))(X_input)
    
   
    X = layers.Conv2D(64, (7,7), strides=(2,2))(X)
    X = layers.BatchNormalization(axis=3)(X)
    X = layers.Activation('relu')(X) 
    X = layers.MaxPooling2D((3,3), strides=(2,2))(X)
    
   
    X = conv_blocks(X, filters=[64,64,256], s=1)
    X = identity_block(X, filters=[64,64,256])
    X = identity_block(X, filters=[64,64,256])
    
   
    X = conv_blocks(X, filters=[128,128,512], s=2)
    X = identity_block(X, filters=[128,128,512])
    X = identity_block(X, filters=[128,128,512])
    X = identity_block(X, filters=[128,128,512])
    
    
    X = conv_blocks(X, filters=[256,256,1024], s=2)
    X = identity_block(X, filters=[256,256,1024])
    X = identity_block(X, filters=[256,256,1024])
    X = identity_block(X, filters=[256,256,1024])
    X = identity_block(X, filters=[256,256,1024])
    X = identity_block(X, filters=[256,256,1024])
    
    
    X = conv_blocks(X, filters=[512,512,2048], s=2)
    X = identity_block(X, filters=[512,512,2048])
    X = identity_block(X, filters=[512,512,2048])
    
    
    X = layers.AveragePooling2D((2,2))(X)
    X = layers.Flatten()(X)
    X = layers.Dense(2, activation='softmax', kernel_initializer='he_normal')(X)
    
    model = keras.Model(inputs=X_input, outputs=X, name='ResNet50')
    
    return model

# %%
model = ResNet50()
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 106, 106, 3)  0          ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 50, 50, 64)   9472        ['zero_padding2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 50, 50, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 50, 50, 64)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 64)   0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 24, 24, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 24, 24, 256)  16640       ['activation_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 24, 24, 256)  16640       ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 24, 24, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 24, 24, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 24, 24, 256)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_4[0][0]']
#
#  activation_3 (Activation)      (None, 24, 24, 256)  0           ['add[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 24, 24, 64)   16448       ['activation_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 24, 24, 256)  16640       ['activation_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 24, 24, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 24, 24, 256)  0           ['batch_normalization_7[0][0]',
#                                                                   'activation_3[0][0]']
#
#  activation_6 (Activation)      (None, 24, 24, 256)  0           ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 24, 24, 64)   16448       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 24, 24, 64)   36928       ['activation_7[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 24, 24, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 24, 24, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 24, 24, 256)  16640       ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 24, 24, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 24, 24, 256)  0           ['batch_normalization_10[0][0]',
#                                                                   'activation_6[0][0]']
#
#  activation_9 (Activation)      (None, 24, 24, 256)  0           ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 128)  32896       ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 12, 12, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 12, 12, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 12, 12, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 12, 12, 512)  66048       ['activation_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 12, 12, 512)  131584      ['activation_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_14[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 12, 12, 512)  0           ['batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  activation_12 (Activation)     (None, 12, 12, 512)  0           ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 128)  65664       ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 12, 12, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 12, 12, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 12, 512)  66048       ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_17[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 12, 12, 512)  0           ['batch_normalization_17[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_15 (Activation)     (None, 12, 12, 512)  0           ['add_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 12, 12, 128)  65664       ['activation_15[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 12, 12, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 12, 12, 128)  147584      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 12, 12, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 12, 12, 512)  66048       ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 12, 12, 512)  0           ['batch_normalization_20[0][0]',
#                                                                   'activation_15[0][0]']
#
#  activation_18 (Activation)     (None, 12, 12, 512)  0           ['add_5[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 12, 12, 128)  65664       ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 12, 12, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 12, 12, 128)  147584      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 12, 12, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 12, 12, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 12, 12, 512)  66048       ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 12, 12, 512)  2048       ['conv2d_23[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 12, 12, 512)  0           ['batch_normalization_23[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_21 (Activation)     (None, 12, 12, 512)  0           ['add_6[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 6, 6, 256)    131328      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 6, 6, 1024)   263168      ['activation_23[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 6, 6, 1024)   525312      ['activation_21[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 6, 6, 1024)  4096        ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 6, 6, 1024)  4096        ['conv2d_27[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 6, 6, 1024)   0           ['batch_normalization_26[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  activation_24 (Activation)     (None, 6, 6, 1024)   0           ['add_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 6, 6, 256)    262400      ['activation_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 6, 6, 1024)   263168      ['activation_26[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 6, 6, 1024)  4096        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 6, 6, 1024)   0           ['batch_normalization_30[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_27 (Activation)     (None, 6, 6, 1024)   0           ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 6, 6, 256)    262400      ['activation_27[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 6, 6, 1024)   263168      ['activation_29[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 6, 6, 1024)  4096        ['conv2d_33[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 6, 6, 1024)   0           ['batch_normalization_33[0][0]',
#                                                                   'activation_27[0][0]']
#
#  activation_30 (Activation)     (None, 6, 6, 1024)   0           ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 6, 6, 256)    262400      ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 6, 6, 1024)   263168      ['activation_32[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 6, 6, 1024)  4096        ['conv2d_36[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 6, 6, 1024)   0           ['batch_normalization_36[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_33 (Activation)     (None, 6, 6, 1024)   0           ['add_10[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 6, 6, 256)    262400      ['activation_33[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_34[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 6, 6, 1024)   263168      ['activation_35[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 6, 6, 1024)  4096        ['conv2d_39[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 6, 6, 1024)   0           ['batch_normalization_39[0][0]',
#                                                                   'activation_33[0][0]']
#
#  activation_36 (Activation)     (None, 6, 6, 1024)   0           ['add_11[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 6, 6, 256)    262400      ['activation_36[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 6, 6, 256)    590080      ['activation_37[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 6, 6, 256)   1024        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 6, 6, 256)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 6, 6, 1024)   263168      ['activation_38[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 6, 6, 1024)  4096        ['conv2d_42[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 6, 6, 1024)   0           ['batch_normalization_42[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 6, 6, 1024)   0           ['add_12[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 3, 3, 512)    524800      ['activation_39[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 3, 3, 512)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 3, 3, 512)    2359808     ['activation_40[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 3, 3, 512)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 3, 3, 2048)   1050624     ['activation_41[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 3, 3, 2048)   2099200     ['activation_39[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 3, 3, 2048)  8192        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 3, 3, 2048)  8192        ['conv2d_46[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 3, 3, 2048)   0           ['batch_normalization_45[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  activation_42 (Activation)     (None, 3, 3, 2048)   0           ['add_13[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 3, 3, 512)    1049088     ['activation_42[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 3, 3, 512)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 3, 3, 512)    2359808     ['activation_43[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 3, 3, 512)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 3, 3, 2048)   1050624     ['activation_44[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 3, 3, 2048)  8192        ['conv2d_49[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 3, 3, 2048)   0           ['batch_normalization_49[0][0]',
#                                                                   'activation_42[0][0]']
#
#  activation_45 (Activation)     (None, 3, 3, 2048)   0           ['add_14[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 3, 3, 512)    1049088     ['activation_45[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 3, 3, 512)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 3, 3, 512)    2359808     ['activation_46[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 3, 3, 512)   2048        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 3, 3, 512)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 3, 3, 2048)   1050624     ['activation_47[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 3, 3, 2048)  8192        ['conv2d_52[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 3, 3, 2048)   0           ['batch_normalization_52[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 3, 3, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 2048)  0           ['activation_48[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 2)            4098        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 23,538,690
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
def lr_schedule(epoch):
    lr = 1e-3
    if epoch > 40:
        lr *= 0.5e-3
    elif epoch > 30:
        lr *= 1e-3
    elif epoch > 20:
        lr *= 1e-2
    elif epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr
lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(lr=lr_schedule(0)), 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)
# Out:
# Learning rate:  0.001
# D:\ML\envs\gpu\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
h = model.fit(train_batch, 
              epochs=50,
              steps_per_epoch = TRAIN_EXAMPLES // BATCH_SIZE,
              validation_data = valid_batch,
              validation_steps = VALIDATION_EXAMPLES // BATCH_SIZE,
              callbacks=lr_scheduler,
              verbose=2
             )
# Out:
# Learning rate:  0.001
# Epoch 1/50
# 145/145 - 33s - loss: 1.0323 - accuracy: 0.5552 - val_loss: 0.7829 - val_accuracy: 0.5052 - lr: 0.0010 - 33s/epoch - 229ms/step
# Learning rate:  0.001
# Epoch 2/50
# 145/145 - 19s - loss: 0.5750 - accuracy: 0.7110 - val_loss: 0.6394 - val_accuracy: 0.6719 - lr: 0.0010 - 19s/epoch - 129ms/step
# Learning rate:  0.001
# Epoch 3/50
# 145/145 - 19s - loss: 0.4412 - accuracy: 0.7975 - val_loss: 0.3857 - val_accuracy: 0.8281 - lr: 0.0010 - 19s/epoch - 129ms/step
# Learning rate:  0.001
# Epoch 4/50
# 145/145 - 19s - loss: 0.3620 - accuracy: 0.8428 - val_loss: 0.5123 - val_accuracy: 0.7917 - lr: 0.0010 - 19s/epoch - 129ms/step
# Learning rate:  0.001
# Epoch 5/50
# 145/145 - 19s - loss: 0.3141 - accuracy: 0.8670 - val_loss: 0.3279 - val_accuracy: 0.8698 - lr: 0.0010 - 19s/epoch - 129ms/step
# Learning rate:  0.001
# Epoch 6/50
# 145/145 - 19s - loss: 0.2721 - accuracy: 0.8930 - val_loss: 0.5207 - val_accuracy: 0.8073 - lr: 0.0010 - 19s/epoch - 130ms/step
# Learning rate:  0.001
# Epoch 7/50
# 145/145 - 19s - loss: 0.2442 - accuracy: 0.9008 - val_loss: 0.3067 - val_accuracy: 0.8906 - lr: 0.0010 - 19s/epoch - 130ms/step
# Learning rate:  0.001
# Epoch 8/50
# 145/145 - 19s - loss: 0.2390 - accuracy: 0.9065 - val_loss: 0.2937 - val_accuracy: 0.8906 - lr: 0.0010 - 19s/epoch - 130ms/step
# Learning rate:  0.001
# Epoch 9/50
# 145/145 - 19s - loss: 0.2571 - accuracy: 0.8965 - val_loss: 0.7682 - val_accuracy: 0.7917 - lr: 0.0010 - 19s/epoch - 130ms/step
# Learning rate:  0.001
# Epoch 10/50
# 145/145 - 19s - loss: 0.2250 - accuracy: 0.9065 - val_loss: 0.1288 - val_accuracy: 0.9531 - lr: 0.0010 - 19s/epoch - 130ms/step
# Learning rate:  0.001
# Epoch 11/50
# 145/145 - 19s - loss: 0.2067 - accuracy: 0.9201 - val_loss: 0.2424 - val_accuracy: 0.9010 - lr: 0.0010 - 19s/epoch - 130ms/step
# Learning rate:  0.0001
# Epoch 12/50
# 145/145 - 19s - loss: 0.1434 - accuracy: 0.9464 - val_loss: 0.1789 - val_accuracy: 0.9375 - lr: 1.0000e-04 - 19s/epoch - 130ms/step
# Learning rate:  0.0001
# Epoch 13/50
# 145/145 - 19s - loss: 0.1228 - accuracy: 0.9544 - val_loss: 0.1241 - val_accuracy: 0.9531 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  0.0001
# Epoch 14/50
# 145/145 - 19s - loss: 0.1159 - accuracy: 0.9573 - val_loss: 0.1517 - val_accuracy: 0.9531 - lr: 1.0000e-04 - 19s/epoch - 132ms/step
# Learning rate:  0.0001
# Epoch 15/50
# 145/145 - 19s - loss: 0.1105 - accuracy: 0.9608 - val_loss: 0.1368 - val_accuracy: 0.9583 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  0.0001
# Epoch 16/50
# 145/145 - 19s - loss: 0.0987 - accuracy: 0.9639 - val_loss: 0.1989 - val_accuracy: 0.9219 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  0.0001
# Epoch 17/50
# 145/145 - 19s - loss: 0.0950 - accuracy: 0.9651 - val_loss: 0.1373 - val_accuracy: 0.9531 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  0.0001
# Epoch 18/50
# 145/145 - 19s - loss: 0.1078 - accuracy: 0.9593 - val_loss: 0.1261 - val_accuracy: 0.9688 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  0.0001
# Epoch 19/50
# 145/145 - 19s - loss: 0.0992 - accuracy: 0.9616 - val_loss: 0.1366 - val_accuracy: 0.9427 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  0.0001
# Epoch 20/50
# 145/145 - 19s - loss: 0.1026 - accuracy: 0.9654 - val_loss: 0.1705 - val_accuracy: 0.9271 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  0.0001
# Epoch 21/50
# 145/145 - 19s - loss: 0.0885 - accuracy: 0.9688 - val_loss: 0.2285 - val_accuracy: 0.9323 - lr: 1.0000e-04 - 19s/epoch - 131ms/step
# Learning rate:  1e-05
# Epoch 22/50
# 145/145 - 19s - loss: 0.0933 - accuracy: 0.9674 - val_loss: 0.1856 - val_accuracy: 0.9323 - lr: 1.0000e-05 - 19s/epoch - 131ms/step
# Learning rate:  1e-05
# Epoch 23/50
# 145/145 - 19s - loss: 0.0729 - accuracy: 0.9743 - val_loss: 0.1083 - val_accuracy: 0.9583 - lr: 1.0000e-05 - 19s/epoch - 132ms/step
# Learning rate:  1e-05
# Epoch 24/50
# 145/145 - 19s - loss: 0.0790 - accuracy: 0.9680 - val_loss: 0.1295 - val_accuracy: 0.9479 - lr: 1.0000e-05 - 19s/epoch - 132ms/step
# Learning rate:  1e-05
# Epoch 25/50
# 145/145 - 19s - loss: 0.0717 - accuracy: 0.9735 - val_loss: 0.1447 - val_accuracy: 0.9323 - lr: 1.0000e-05 - 19s/epoch - 131ms/step
# Learning rate:  1e-05
# Epoch 26/50
# 145/145 - 19s - loss: 0.0719 - accuracy: 0.9735 - val_loss: 0.1453 - val_accuracy: 0.9323 - lr: 1.0000e-05 - 19s/epoch - 131ms/step
# Learning rate:  1e-05
# Epoch 27/50
# 145/145 - 19s - loss: 0.0718 - accuracy: 0.9755 - val_loss: 0.1525 - val_accuracy: 0.9323 - lr: 1.0000e-05 - 19s/epoch - 131ms/step
# Learning rate:  1e-05
# Epoch 28/50
# 145/145 - 19s - loss: 0.0664 - accuracy: 0.9775 - val_loss: 0.1552 - val_accuracy: 0.9427 - lr: 1.0000e-05 - 19s/epoch - 131ms/step
# Learning rate:  1e-05
# Epoch 29/50
# 145/145 - 19s - loss: 0.0718 - accuracy: 0.9740 - val_loss: 0.1348 - val_accuracy: 0.9427 - lr: 1.0000e-05 - 19s/epoch - 131ms/step
# Learning rate:  1e-05
# Epoch 30/50
# 145/145 - 19s - loss: 0.0610 - accuracy: 0.9798 - val_loss: 0.1652 - val_accuracy: 0.9531 - lr: 1.0000e-05 - 19s/epoch - 132ms/step
# Learning rate:  1e-05
# Epoch 31/50
# 145/145 - 19s - loss: 0.0674 - accuracy: 0.9775 - val_loss: 0.1150 - val_accuracy: 0.9531 - lr: 1.0000e-05 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 32/50
# 145/145 - 19s - loss: 0.0719 - accuracy: 0.9720 - val_loss: 0.1628 - val_accuracy: 0.9323 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 33/50
# 145/145 - 19s - loss: 0.0616 - accuracy: 0.9787 - val_loss: 0.1439 - val_accuracy: 0.9531 - lr: 1.0000e-06 - 19s/epoch - 132ms/step
# Learning rate:  1e-06
# Epoch 34/50
# 145/145 - 19s - loss: 0.0627 - accuracy: 0.9781 - val_loss: 0.1692 - val_accuracy: 0.9427 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 35/50
# 145/145 - 19s - loss: 0.0634 - accuracy: 0.9789 - val_loss: 0.1469 - val_accuracy: 0.9635 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 36/50
# 145/145 - 19s - loss: 0.0635 - accuracy: 0.9763 - val_loss: 0.1394 - val_accuracy: 0.9583 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 37/50
# 145/145 - 19s - loss: 0.0691 - accuracy: 0.9778 - val_loss: 0.1969 - val_accuracy: 0.9323 - lr: 1.0000e-06 - 19s/epoch - 132ms/step
# Learning rate:  1e-06
# Epoch 38/50
# 145/145 - 19s - loss: 0.0643 - accuracy: 0.9798 - val_loss: 0.2401 - val_accuracy: 0.9323 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 39/50
# 145/145 - 19s - loss: 0.0696 - accuracy: 0.9784 - val_loss: 0.1489 - val_accuracy: 0.9531 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 40/50
# 145/145 - 19s - loss: 0.0626 - accuracy: 0.9749 - val_loss: 0.1524 - val_accuracy: 0.9531 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  1e-06
# Epoch 41/50
# 145/145 - 19s - loss: 0.0752 - accuracy: 0.9720 - val_loss: 0.1418 - val_accuracy: 0.9479 - lr: 1.0000e-06 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 42/50
# 145/145 - 19s - loss: 0.0626 - accuracy: 0.9766 - val_loss: 0.1427 - val_accuracy: 0.9531 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 43/50
# 145/145 - 19s - loss: 0.0605 - accuracy: 0.9758 - val_loss: 0.2014 - val_accuracy: 0.9531 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 44/50
# 145/145 - 19s - loss: 0.0638 - accuracy: 0.9769 - val_loss: 0.1809 - val_accuracy: 0.9427 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 45/50
# 145/145 - 19s - loss: 0.0653 - accuracy: 0.9743 - val_loss: 0.1054 - val_accuracy: 0.9635 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 46/50
# 145/145 - 19s - loss: 0.0594 - accuracy: 0.9775 - val_loss: 0.1644 - val_accuracy: 0.9531 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 47/50
# 145/145 - 19s - loss: 0.0592 - accuracy: 0.9815 - val_loss: 0.1207 - val_accuracy: 0.9635 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 48/50
# 145/145 - 19s - loss: 0.0627 - accuracy: 0.9813 - val_loss: 0.1921 - val_accuracy: 0.9323 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 49/50
# 145/145 - 19s - loss: 0.0594 - accuracy: 0.9784 - val_loss: 0.1329 - val_accuracy: 0.9375 - lr: 5.0000e-07 - 19s/epoch - 131ms/step
# Learning rate:  5e-07
# Epoch 50/50
# 145/145 - 19s - loss: 0.0718 - accuracy: 0.9752 - val_loss: 0.1454 - val_accuracy: 0.9531 - lr: 5.0000e-07 - 19s/epoch - 131ms/step

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'],  label='train accuracy')
plt.plot(h.history['val_accuracy'],  label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'],  label='train loss')
plt.plot(h.history['val_loss'],  label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.ylim([0,1])
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # --------CNN Architecture-------

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_male_dir = os.path.join('D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/train/male/')


train_female_dir = os.path.join('D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/train/female/')


validation_male_dir = os.path.join('D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/valid/male/')


validation_female_dir = os.path.join('D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/valid/female/')

# %%
model_cnn = tf.keras.models.Sequential([
   
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    
    tf.keras.layers.Dense(512, activation='relu'),
    
    tf.keras.layers.Dropout(0.3), 
    
    tf.keras.layers.Dense(512, activation='relu'),
    
    tf.keras.layers.Dropout(0.3), 
    
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model_cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_53 (Conv2D)          (None, 98, 98, 32)        896
#
#  max_pooling2d_1 (MaxPooling  (None, 49, 49, 32)       0
#  2D)
#
#  conv2d_54 (Conv2D)          (None, 47, 47, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_55 (Conv2D)          (None, 21, 21, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_56 (Conv2D)          (None, 8, 8, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  conv2d_57 (Conv2D)          (None, 2, 2, 128)         73856
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 512)               66048
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 469,154
# Trainable params: 469,154
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_cnn.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=keras.optimizers.Adam(lr=lr_schedule(0)),
    metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
train_datagen = ImageDataGenerator(rescale=1/255)
validation_datagen = ImageDataGenerator(rescale=1/255)


train_generator = train_datagen.flow_from_directory(
        'D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/train/',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='sparse',
        shuffle=True)


validation_generator = validation_datagen.flow_from_directory(
        'D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/valid/',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='sparse')
# Out:
# Found 3491 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
history_cnn = model_cnn.fit(
      train_generator,
      steps_per_epoch=32,  
      epochs=50,
      verbose=1,
      validation_data = validation_generator
      )
# Out:
# Epoch 1/50
# 32/32 [==============================] - 2s 32ms/step - loss: 0.6952 - accuracy: 0.5086 - val_loss: 0.6982 - val_accuracy: 0.5000
# Epoch 2/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.6910 - accuracy: 0.5091 - val_loss: 0.6612 - val_accuracy: 0.6300
# Epoch 3/50
# 32/32 [==============================] - 1s 15ms/step - loss: 0.6346 - accuracy: 0.6419 - val_loss: 0.6852 - val_accuracy: 0.5900
# Epoch 4/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.5469 - accuracy: 0.7370 - val_loss: 0.5253 - val_accuracy: 0.7500
# Epoch 5/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.4983 - accuracy: 0.7708 - val_loss: 0.3683 - val_accuracy: 0.8400
# Epoch 6/50
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4286 - accuracy: 0.8216 - val_loss: 0.2859 - val_accuracy: 0.8650
# Epoch 7/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.3782 - accuracy: 0.8568 - val_loss: 0.3025 - val_accuracy: 0.8800
# Epoch 8/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.3349 - accuracy: 0.8607 - val_loss: 0.3828 - val_accuracy: 0.8800
# Epoch 9/50
# 32/32 [==============================] - 1s 15ms/step - loss: 0.3143 - accuracy: 0.8646 - val_loss: 0.3665 - val_accuracy: 0.8550
# Epoch 10/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.2585 - accuracy: 0.8932 - val_loss: 0.3645 - val_accuracy: 0.8750
# Epoch 11/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.2734 - accuracy: 0.8874 - val_loss: 0.2615 - val_accuracy: 0.9050
# Epoch 12/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2172 - accuracy: 0.9206 - val_loss: 0.2874 - val_accuracy: 0.8950
# Epoch 13/50
# 32/32 [==============================] - 1s 19ms/step - loss: 0.2287 - accuracy: 0.9102 - val_loss: 0.2094 - val_accuracy: 0.9200
# Epoch 14/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2898 - accuracy: 0.8789 - val_loss: 0.2736 - val_accuracy: 0.9000
# Epoch 15/50
# 32/32 [==============================] - 1s 15ms/step - loss: 0.2634 - accuracy: 0.8841 - val_loss: 0.2005 - val_accuracy: 0.9100
# Epoch 16/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.2253 - accuracy: 0.9154 - val_loss: 0.2366 - val_accuracy: 0.9250
# Epoch 17/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2363 - accuracy: 0.9023 - val_loss: 0.2397 - val_accuracy: 0.9100
# Epoch 18/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1904 - accuracy: 0.9141 - val_loss: 0.4462 - val_accuracy: 0.8150
# Epoch 19/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2097 - accuracy: 0.9245 - val_loss: 0.1927 - val_accuracy: 0.9200
# Epoch 20/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.1760 - accuracy: 0.9323 - val_loss: 0.1767 - val_accuracy: 0.9400
# Epoch 21/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.1927 - accuracy: 0.9349 - val_loss: 0.2741 - val_accuracy: 0.8800
# Epoch 22/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.2082 - accuracy: 0.9193 - val_loss: 0.1640 - val_accuracy: 0.9350
# Epoch 23/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1782 - accuracy: 0.9310 - val_loss: 0.2884 - val_accuracy: 0.8900
# Epoch 24/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1554 - accuracy: 0.9466 - val_loss: 0.2054 - val_accuracy: 0.9250
# Epoch 25/50
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1654 - accuracy: 0.9466 - val_loss: 0.2052 - val_accuracy: 0.9350
# Epoch 26/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1458 - accuracy: 0.9427 - val_loss: 0.2084 - val_accuracy: 0.9000
# Epoch 27/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.1527 - accuracy: 0.9414 - val_loss: 0.2040 - val_accuracy: 0.9200
# Epoch 28/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1291 - accuracy: 0.9479 - val_loss: 0.3839 - val_accuracy: 0.8600
# Epoch 29/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1321 - accuracy: 0.9576 - val_loss: 0.3180 - val_accuracy: 0.9000
# Epoch 30/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.1385 - accuracy: 0.9557 - val_loss: 0.1835 - val_accuracy: 0.9250
# Epoch 31/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1308 - accuracy: 0.9523 - val_loss: 0.1484 - val_accuracy: 0.9450
# Epoch 32/50
# 32/32 [==============================] - 1s 20ms/step - loss: 0.1071 - accuracy: 0.9648 - val_loss: 0.2350 - val_accuracy: 0.9300
# Epoch 33/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1271 - accuracy: 0.9492 - val_loss: 0.2001 - val_accuracy: 0.9300
# Epoch 34/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1421 - accuracy: 0.9483 - val_loss: 0.1878 - val_accuracy: 0.9200
# Epoch 35/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0660 - accuracy: 0.9766 - val_loss: 0.2605 - val_accuracy: 0.9250
# Epoch 36/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1590 - accuracy: 0.9479 - val_loss: 0.2032 - val_accuracy: 0.9400
# Epoch 37/50
# 32/32 [==============================] - 1s 18ms/step - loss: 0.1195 - accuracy: 0.9505 - val_loss: 0.1932 - val_accuracy: 0.9400
# Epoch 38/50
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0995 - accuracy: 0.9583 - val_loss: 0.2337 - val_accuracy: 0.9300
# Epoch 39/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0889 - accuracy: 0.9714 - val_loss: 0.2615 - val_accuracy: 0.9250
# Epoch 40/50
# 32/32 [==============================] - 1s 19ms/step - loss: 0.1499 - accuracy: 0.9466 - val_loss: 0.1737 - val_accuracy: 0.9350
# Epoch 41/50
# 32/32 [==============================] - 1s 19ms/step - loss: 0.0954 - accuracy: 0.9722 - val_loss: 0.1607 - val_accuracy: 0.9450
# Epoch 42/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.1043 - accuracy: 0.9635 - val_loss: 0.1672 - val_accuracy: 0.9500
# Epoch 43/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1055 - accuracy: 0.9570 - val_loss: 0.1897 - val_accuracy: 0.9400
# Epoch 44/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0779 - accuracy: 0.9701 - val_loss: 0.1907 - val_accuracy: 0.9450
# Epoch 45/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.0697 - accuracy: 0.9775 - val_loss: 0.1950 - val_accuracy: 0.9450
# Epoch 46/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0608 - accuracy: 0.9805 - val_loss: 0.2523 - val_accuracy: 0.9300
# Epoch 47/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.1184 - accuracy: 0.9544 - val_loss: 0.1780 - val_accuracy: 0.9300
# Epoch 48/50
# 32/32 [==============================] - 1s 18ms/step - loss: 0.0922 - accuracy: 0.9727 - val_loss: 0.2531 - val_accuracy: 0.9350
# Epoch 49/50
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0627 - accuracy: 0.9828 - val_loss: 0.2251 - val_accuracy: 0.9350
# Epoch 50/50
# 32/32 [==============================] - 1s 16ms/step - loss: 0.1266 - accuracy: 0.9544 - val_loss: 0.1910 - val_accuracy: 0.9250

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(history_cnn.history['accuracy'],  label='train accuracy')
plt.plot(history_cnn.history['val_accuracy'],  label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(history_cnn.history['loss'],  label='train loss')
plt.plot(history_cnn.history['val_loss'],  label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.ylim([0,1])
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # -------VGG16----------

# %%
from glob import glob
training_dir=TRAIN_DIR
validation_dir=VALID_DIR
image_files = glob(training_dir + '/*/*')
valid_image_files = glob(validation_dir + '/*/*')

# %%
folders = glob(training_dir + '/*')
num_classes = len(folders)
print ('Total Classes = ' + str(num_classes))
# Out:
# Total Classes = 2

# %%
from keras.models import Model
from keras.layers import Flatten, Dense
from tensorflow.keras.applications.vgg16 import VGG16

IMG_SIZE=80

IMAGE_SIZE = [IMG_SIZE, IMG_SIZE] 


vgg = VGG16(input_shape = IMAGE_SIZE + [3], weights = 'imagenet', include_top = False) 


for layer in vgg.layers:
    layer.trainable = False

x = Flatten()(vgg.output)

x = Dense(num_classes, activation = 'softmax')(x)  

model = Model(inputs = vgg.input, outputs = x)

model.compile(
    loss='sparse_categorical_crossentropy', 
    optimizer='Adam', 
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 80, 80, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 80, 80, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 80, 80, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 40, 40, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 40, 40, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 40, 40, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 20, 20, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 20, 20, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 20, 20, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 20, 20, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 10, 10, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 10, 10, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 10, 10, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 5, 5, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 5, 5, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 5, 5, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 2)                 4098
#
# =================================================================
# Total params: 14,718,786
# Trainable params: 4,098
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
training_datagen = ImageDataGenerator(
                                    rescale=1./255,
                                    shear_range=0.2, 
                                    zoom_range=0.2,
                                    horizontal_flip=False,
                                    preprocessing_function=preprocess_input)

validation_datagen = ImageDataGenerator(rescale = 1./255, preprocessing_function=preprocess_input)

training_generator = training_datagen.flow_from_directory(
    training_dir, 
    target_size = IMAGE_SIZE, 
    batch_size = BATCH_SIZE, 
    class_mode = 'sparse')

validation_generator = validation_datagen.flow_from_directory(
    validation_dir, 
    target_size = IMAGE_SIZE, 
    batch_size = BATCH_SIZE, 
    class_mode = 'sparse')
# Out:
# Found 3491 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
training_images = 3491
validation_images = 200

history = model.fit(training_generator,
                   steps_per_epoch = 20,
                   epochs = 50,
                   validation_data = validation_generator,
                   )
# Out:
# Epoch 1/50
# 20/20 [==============================] - 4s 103ms/step - loss: 0.6806 - accuracy: 0.5729 - val_loss: 0.5585 - val_accuracy: 0.7550
# Epoch 2/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.5569 - accuracy: 0.7396 - val_loss: 0.5511 - val_accuracy: 0.6900
# Epoch 3/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.4777 - accuracy: 0.7937 - val_loss: 0.4476 - val_accuracy: 0.8100
# Epoch 4/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.4583 - accuracy: 0.8083 - val_loss: 0.4546 - val_accuracy: 0.7700
# Epoch 5/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.4347 - accuracy: 0.8146 - val_loss: 0.4194 - val_accuracy: 0.8200
# Epoch 6/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3947 - accuracy: 0.8354 - val_loss: 0.4071 - val_accuracy: 0.8200
# Epoch 7/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.4015 - accuracy: 0.8375 - val_loss: 0.3868 - val_accuracy: 0.8050
# Epoch 8/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3525 - accuracy: 0.8687 - val_loss: 0.3571 - val_accuracy: 0.8500
# Epoch 9/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3455 - accuracy: 0.8771 - val_loss: 0.3982 - val_accuracy: 0.8050
# Epoch 10/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3522 - accuracy: 0.8396 - val_loss: 0.3292 - val_accuracy: 0.8500
# Epoch 11/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3459 - accuracy: 0.8792 - val_loss: 0.3321 - val_accuracy: 0.8600
# Epoch 12/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3040 - accuracy: 0.8729 - val_loss: 0.3473 - val_accuracy: 0.8550
# Epoch 13/50
# 20/20 [==============================] - 1s 56ms/step - loss: 0.3466 - accuracy: 0.8604 - val_loss: 0.3177 - val_accuracy: 0.8550
# Epoch 14/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3054 - accuracy: 0.8792 - val_loss: 0.3342 - val_accuracy: 0.8550
# Epoch 15/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3211 - accuracy: 0.8771 - val_loss: 0.3309 - val_accuracy: 0.8650
# Epoch 16/50
# 20/20 [==============================] - 2s 104ms/step - loss: 0.3081 - accuracy: 0.8801 - val_loss: 0.3149 - val_accuracy: 0.8550
# Epoch 17/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3231 - accuracy: 0.8562 - val_loss: 0.3146 - val_accuracy: 0.8750
# Epoch 18/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3203 - accuracy: 0.8813 - val_loss: 0.2823 - val_accuracy: 0.8850
# Epoch 19/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.3060 - accuracy: 0.8646 - val_loss: 0.3100 - val_accuracy: 0.8650
# Epoch 20/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2794 - accuracy: 0.8979 - val_loss: 0.2876 - val_accuracy: 0.8700
# Epoch 21/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3306 - accuracy: 0.8687 - val_loss: 0.3085 - val_accuracy: 0.8700
# Epoch 22/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3225 - accuracy: 0.8729 - val_loss: 0.2894 - val_accuracy: 0.8650
# Epoch 23/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2758 - accuracy: 0.8958 - val_loss: 0.2891 - val_accuracy: 0.8650
# Epoch 24/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2637 - accuracy: 0.9000 - val_loss: 0.2903 - val_accuracy: 0.8650
# Epoch 25/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2786 - accuracy: 0.9042 - val_loss: 0.3064 - val_accuracy: 0.8700
# Epoch 26/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3035 - accuracy: 0.8887 - val_loss: 0.2765 - val_accuracy: 0.8800
# Epoch 27/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.3035 - accuracy: 0.8813 - val_loss: 0.2618 - val_accuracy: 0.8850
# Epoch 28/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2868 - accuracy: 0.8854 - val_loss: 0.2884 - val_accuracy: 0.8650
# Epoch 29/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2784 - accuracy: 0.8938 - val_loss: 0.2912 - val_accuracy: 0.8700
# Epoch 30/50
# 20/20 [==============================] - 1s 60ms/step - loss: 0.3227 - accuracy: 0.8604 - val_loss: 0.2593 - val_accuracy: 0.9000
# Epoch 31/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.3079 - accuracy: 0.8672 - val_loss: 0.2548 - val_accuracy: 0.9050
# Epoch 32/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2775 - accuracy: 0.8750 - val_loss: 0.2822 - val_accuracy: 0.8750
# Epoch 33/50
# 20/20 [==============================] - 1s 57ms/step - loss: 0.2580 - accuracy: 0.8844 - val_loss: 0.2628 - val_accuracy: 0.8850
# Epoch 34/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2823 - accuracy: 0.8854 - val_loss: 0.2618 - val_accuracy: 0.8900
# Epoch 35/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2859 - accuracy: 0.8917 - val_loss: 0.3451 - val_accuracy: 0.8350
# Epoch 36/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2701 - accuracy: 0.8979 - val_loss: 0.2794 - val_accuracy: 0.8800
# Epoch 37/50
# 20/20 [==============================] - 1s 62ms/step - loss: 0.2232 - accuracy: 0.9208 - val_loss: 0.2635 - val_accuracy: 0.8750
# Epoch 38/50
# 20/20 [==============================] - 1s 64ms/step - loss: 0.2915 - accuracy: 0.8708 - val_loss: 0.2472 - val_accuracy: 0.8900
# Epoch 39/50
# 20/20 [==============================] - 1s 63ms/step - loss: 0.2973 - accuracy: 0.8715 - val_loss: 0.2593 - val_accuracy: 0.8800
# Epoch 40/50
# 20/20 [==============================] - 1s 61ms/step - loss: 0.2601 - accuracy: 0.9062 - val_loss: 0.2698 - val_accuracy: 0.8650
# Epoch 41/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2512 - accuracy: 0.9167 - val_loss: 0.2806 - val_accuracy: 0.8750
# Epoch 42/50
# 20/20 [==============================] - 1s 59ms/step - loss: 0.2452 - accuracy: 0.9104 - val_loss: 0.2795 - val_accuracy: 0.8700
# Epoch 43/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2379 - accuracy: 0.9125 - val_loss: 0.2645 - val_accuracy: 0.8850
# Epoch 44/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2437 - accuracy: 0.9146 - val_loss: 0.2656 - val_accuracy: 0.8800
# Epoch 45/50
# 20/20 [==============================] - 1s 61ms/step - loss: 0.2705 - accuracy: 0.8854 - val_loss: 0.2584 - val_accuracy: 0.8800
# Epoch 46/50
# 20/20 [==============================] - 1s 62ms/step - loss: 0.2803 - accuracy: 0.8646 - val_loss: 0.2679 - val_accuracy: 0.8750
# Epoch 47/50
# 20/20 [==============================] - 1s 61ms/step - loss: 0.2777 - accuracy: 0.8875 - val_loss: 0.2834 - val_accuracy: 0.8800
# Epoch 48/50
# 20/20 [==============================] - 1s 58ms/step - loss: 0.2045 - accuracy: 0.9315 - val_loss: 0.2780 - val_accuracy: 0.8850
# Epoch 49/50
# 20/20 [==============================] - 1s 59ms/step - loss: 0.2686 - accuracy: 0.8771 - val_loss: 0.2762 - val_accuracy: 0.8750
# Epoch 50/50
# 20/20 [==============================] - 1s 63ms/step - loss: 0.2773 - accuracy: 0.8875 - val_loss: 0.2985 - val_accuracy: 0.8600

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],  label='train accuracy')
plt.plot(history.history['val_accuracy'],  label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(history.history['loss'],  label='train loss')
plt.plot(history.history['val_loss'],  label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.ylim([0,1])
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # -------Filter Visualization (VGG16)-------

# %%
model = vgg

for i in range(len(model.layers)):
    layer = model.layers[i]

    if 'conv' not in layer.name:
        continue

    print(i, layer.name, layer.output.shape)
# Out:
# 1 block1_conv1 (None, 80, 80, 64)
# 2 block1_conv2 (None, 80, 80, 64)
# 4 block2_conv1 (None, 40, 40, 128)
# 5 block2_conv2 (None, 40, 40, 128)
# 7 block3_conv1 (None, 20, 20, 256)
# 8 block3_conv2 (None, 20, 20, 256)
# 9 block3_conv3 (None, 20, 20, 256)
# 11 block4_conv1 (None, 10, 10, 512)
# 12 block4_conv2 (None, 10, 10, 512)
# 13 block4_conv3 (None, 10, 10, 512)
# 15 block5_conv1 (None, 5, 5, 512)
# 16 block5_conv2 (None, 5, 5, 512)
# 17 block5_conv3 (None, 5, 5, 512)

# %%
model = Model(inputs=model.inputs, outputs=model.layers[1].output)

# %%
img = tf.keras.utils.load_img('D:/ML/envs/gpu/Datasets/Gender_classification/gender_rev2/train/male/0019.jpg', target_size=(IMG_SIZE, IMG_SIZE))

# %%
img = tf.keras.utils.img_to_array(img)
img = np.expand_dims(img, axis=0)

# %%
img = preprocess_input(img)

# %%
feature_maps = model.predict(img)

# %%
square = 8
ix = 1
plt.figure(figsize=(20,20))

for _ in range(square):
    for _ in range(square):
        
        ax = plt.subplot(square, square, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        
        plt.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
        ix += 1

plt.show()
